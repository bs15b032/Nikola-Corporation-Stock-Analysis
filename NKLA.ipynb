# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import yfinance as yf

# %%
start = "2018-06-11"
end = '2022-06-29'
nkla = yf.download('NKLA',start,end)
nkla
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2018-06-11  9.57  9.58  9.57   9.58       9.58    402600
# 2018-06-12  9.56  9.56  9.56   9.56       9.56    300000
# 2018-06-13  9.57  9.58  9.56   9.57       9.57    179100
# 2018-06-14  9.57  9.57  9.57   9.57       9.57         0
# 2018-06-15  9.57  9.57  9.57   9.57       9.57         0
# ...          ...   ...   ...    ...        ...       ...
# 2022-06-22  5.57  5.86  5.48   5.60       5.60   8484600
# 2022-06-23  5.60  5.68  5.41   5.67       5.67   7665800
# 2022-06-24  5.73  5.84  5.49   5.61       5.61  16161200
# 2022-06-27  5.60  5.74  5.31   5.39       5.39  11042300
# 2022-06-28  5.38  5.45  5.05   5.08       5.08  11478100
#
# [1020 rows x 6 columns]

# %%
nkla['Volume'].plot(label = 'nkla',figsize=(16,8))
plt.title('Volume of Stock traded')
plt.legend()

# %%
nkla['MA50'] = nkla['Open'].rolling(50).mean()
nkla['MA200'] = nkla['Open'].rolling(200).mean()
nkla['Open'].plot(figsize = (15,7))
nkla['MA50'].plot()
nkla['MA200'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
nkla['returns'] = (nkla['Close']/nkla['Close'].shift(1)) -1


nkla['returns'].hist(bins = 100, label = 'NKLA', alpha = 0.5, figsize = (15,7))

plt.legend()

# %%
nkla['Daily_Return_Pct']=(nkla['Adj Close']/nkla['Adj Close'].shift(1))-1
nkla
# Out:
#             Open  High   Low  Close  Adj Close    Volume     MA50     MA200  \
# Date
# 2018-06-11  9.57  9.58  9.57   9.58       9.58    402600      NaN       NaN
# 2018-06-12  9.56  9.56  9.56   9.56       9.56    300000      NaN       NaN
# 2018-06-13  9.57  9.58  9.56   9.57       9.57    179100      NaN       NaN
# 2018-06-14  9.57  9.57  9.57   9.57       9.57         0      NaN       NaN
# 2018-06-15  9.57  9.57  9.57   9.57       9.57         0      NaN       NaN
# ...          ...   ...   ...    ...        ...       ...      ...       ...
# 2022-06-22  5.57  5.86  5.48   5.60       5.60   8484600  6.73924  9.138525
# 2022-06-23  5.60  5.68  5.41   5.67       5.67   7665800  6.68564  9.113775
# 2022-06-24  5.73  5.84  5.49   5.61       5.61  16161200  6.63104  9.089230
# 2022-06-27  5.60  5.74  5.31   5.39       5.39  11042300  6.58044  9.067230
# 2022-06-28  5.38  5.45  5.05   5.08       5.08  11478100  6.52464  9.044415
#
#              returns  Daily_Return_Pct
# Date
# 2018-06-11       NaN               NaN
# 2018-06-12 -0.002088         -0.002088
# 2018-06-13  0.001046          0.001046
# 2018-06-14  0.000000          0.000000
# 2018-06-15  0.000000          0.000000
# ...              ...               ...
# 2022-06-22 -0.019264         -0.019264
# 2022-06-23  0.012500          0.012500
# 2022-06-24 -0.010582         -0.010582
# 2022-06-27 -0.039216         -0.039216
# 2022-06-28 -0.057514         -0.057514
#
# [1020 rows x 10 columns]
